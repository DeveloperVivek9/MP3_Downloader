# %%
# !pip install shazamio
# Out:
# Collecting shazamio
#   Downloading shazamio-0.3.1.1-py3-none-any.whl (31 kB)
# Collecting pydub<0.26.0,>=0.25.1
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting dataclass-factory==2.16
#   Downloading dataclass_factory-2.16-py3-none-any.whl (29 kB)
# Collecting pytest-asyncio<0.21.0,>=0.20.3
#   Downloading pytest_asyncio-0.20.3-py3-none-any.whl (12 kB)
# Collecting pydantic<2.0.0,>=1.10.2
#   Downloading pydantic-1.10.4-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 12.4 MB/s eta 0:00:00
# Collecting pytest<8.0.0,>=7.2.0
#   Downloading pytest-7.2.1-py3-none-any.whl (317 kB)
#      ------------------------------------- 317.1/317.1 kB 20.5 MB/s eta 0:00:00
# Collecting numpy<2.0.0,>=1.24.0
#   Downloading numpy-1.24.1-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 5.7 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.8.3-cp39-cp39-win_amd64.whl (323 kB)
#      -------------------------------------- 323.5/323.5 kB 6.7 MB/s eta 0:00:00
# Collecting anyio<4.0.0,>=3.6.2
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting aiofiles<23.0.0,>=22.1.0
#   Downloading aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\arviv\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->shazamio) (2.0.4)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in c:\users\arviv\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->shazamio) (21.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\arviv\anaconda3\lib\site-packages (from anyio<4.0.0,>=3.6.2->shazamio) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\arviv\anaconda3\lib\site-packages (from anyio<4.0.0,>=3.6.2->shazamio) (2.10)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\arviv\anaconda3\lib\site-packages (from pydantic<2.0.0,>=1.10.2->shazamio) (4.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (2.0.1)
# Requirement already satisfied: packaging in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (1.0.0)
# Requirement already satisfied: colorama in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (0.4.5)
# Requirement already satisfied: iniconfig in c:\users\arviv\anaconda3\lib\site-packages (from pytest<8.0.0,>=7.2.0->shazamio) (1.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arviv\anaconda3\lib\site-packages (from packaging->pytest<8.0.0,>=7.2.0->shazamio) (2.4.7)
# Installing collected packages: pydub, pydantic, numpy, multidict, frozenlist, dataclass-factory, async-timeout, anyio, aiofiles, yarl, pytest, aiosignal, pytest-asyncio, aiohttp, shazamio
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.1.2
#     Uninstalling pytest-7.1.2:
#       Successfully uninstalled pytest-7.1.2
# Successfully installed aiofiles-22.1.0 aiohttp-3.8.3 aiosignal-1.3.1 anyio-3.6.2 async-timeout-4.0.2 dataclass-factory-2.16 frozenlist-1.3.3 multidict-6.0.4 numpy-1.24.1 pydantic-1.10.4 pydub-0.25.1 pytest-7.2.1 pytest-asyncio-0.20.3 shazamio-0.3.1.1 yarl-1.8.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.1 which is incompatible.

# %%
# !pip install ShazamAPI
# Out:
# Collecting ShazamAPI
#   Downloading ShazamAPI-0.0.2-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pydub in c:\users\arviv\anaconda3\lib\site-packages (from ShazamAPI) (0.25.1)
# Requirement already satisfied: requests in c:\users\arviv\anaconda3\lib\site-packages (from ShazamAPI) (2.28.1)
# Requirement already satisfied: numpy in c:\users\arviv\anaconda3\lib\site-packages (from ShazamAPI) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arviv\anaconda3\lib\site-packages (from requests->ShazamAPI) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\arviv\anaconda3\lib\site-packages (from requests->ShazamAPI) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\arviv\anaconda3\lib\site-packages (from requests->ShazamAPI) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arviv\anaconda3\lib\site-packages (from requests->ShazamAPI) (3.4)
# Installing collected packages: ShazamAPI
# Successfully installed ShazamAPI-0.0.2

# %%
#!conda install -c main ffmpeg

# %%
from glob import glob
import itertools
import os
import time
from ShazamAPI import Shazam

# %%
async def main():
  shazam = Shazam()
  out = await shazam.recognize_song('dora.ogg')
  print(out)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15532\1360277989.py in <module>
#       9
#      10 loop = asyncio.get_event_loop()
# ---> 11 loop.run_until_complete(main())
#
# ~\anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     621         """
#     622         self._check_closed()
# --> 623         self._check_running()
#     624
#     625         new_task = not futures.isfuture(future)
#
# ~\anaconda3\lib\asyncio\base_events.py in _check_running(self)
#     581     def _check_running(self):
#     582         if self.is_running():
# --> 583             raise RuntimeError('This event loop is already running')
#     584         if events._get_running_loop() is not None:
#     585             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
mp3_file_content_to_recognize = open('(G)I-DLE - HANN (Alone).mp3', 'rb').read()

shazam = Shazam(mp3_file_content_to_recognize)
recognize_generator = shazam.recognizeSong()
#while True:
	#print(next(recognize_generator)) # current offset & shazam response to recognize requests
# Out:
# (14.0, {'matches': [{'id': '435859252', 'offset': 6.0004516599999995, 'timeskew': 0.0002272129, 'frequencyskew': -0.000120818615}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854015836, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://i ...
# (22.0, {'matches': [{'id': '435859252', 'offset': 14.004170898, 'timeskew': -0.00020545721, 'frequencyskew': -4.029274e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854019839, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images. ...
# (30.0, {'matches': [{'id': '435859252', 'offset': 22.003396484, 'timeskew': -0.00019007921, 'frequencyskew': -8.0525875e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854023802, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images ...
# (38.0, {'matches': [{'id': '435859252', 'offset': 30.001474609000002, 'timeskew': 0.00019192696, 'frequencyskew': 0.0}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854027789, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images.shaza ...
# (46.0, {'matches': [{'id': '435859252', 'offset': 38.000140625, 'timeskew': 0.0001963377, 'frequencyskew': -0.000120818615}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854031796, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images. ...
# (54.0, {'matches': [{'id': '435859252', 'offset': 46.003664062000006, 'timeskew': -0.00010472536, 'frequencyskew': 0.0}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854035846, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images.shaz ...
# (62.0, {'matches': [{'id': '435859252', 'offset': 54.001910156, 'timeskew': -4.374981e-05, 'frequencyskew': -6.443262e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854039825, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images.s ...
# (70.0, {'matches': [{'id': '435859252', 'offset': 62.002757812000006, 'timeskew': 3.9696693e-05, 'frequencyskew': -8.0525875e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854044068, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://i ...
# (78.0, {'matches': [{'id': '435859252', 'offset': 69.999640625, 'timeskew': 0.00035369396, 'frequencyskew': 0.0}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854048063, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images.shazam.com/ ...
# (86.0, {'matches': [{'id': '435859252', 'offset': 78.00190625, 'timeskew': 6.4492226e-05, 'frequencyskew': 0.0}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854052058, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images.shazam.com/s ...
# (94.0, {'matches': [{'id': '435859252', 'offset': 86.003609375, 'timeskew': -7.2181225e-05, 'frequencyskew': -0.00016111135}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854056051, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images ...
# ...
# (190.0, {'matches': [{'id': '435859252', 'offset': 182.001609375, 'timeskew': -3.796816e-05, 'frequencyskew': -0.000120818615}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854104129, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://imag ...
# (198.0, {'matches': [{'id': '435859252', 'offset': 190.000953125, 'timeskew': 0.00011408329, 'frequencyskew': -8.0525875e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854108092, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://image ...
# (205.816, {'matches': [{'id': '435859252', 'offset': 197.999875, 'timeskew': 0.00028431416, 'frequencyskew': -4.029274e-05}], 'location': {'accuracy': 0.01}, 'timestamp': 1673854112165, 'timezone': 'Europe/Moscow', 'track': {'layout': '5', 'type': 'MUSIC', 'key': '435859252', 'title': 'Hann (Alone)', 'subtitle': '(G)I-DLE', 'images': {'background': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'coverart': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'coverarthq': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'joecolor': 'b:1c1920p:ffffffs:acaec9t:d1d0d2q:8f90a7'}, 'share': {'subject': 'Hann (Alone) - (G)I-DLE', 'text': 'Мое открытие на Shazam: (G)I-DLE - Hann (Alone).', 'href': 'https://www.shazam.com/track/435859252/hann-alone', 'image': 'https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/ef/02/33/ef0233f1-2a15-5af4-1634-2ab68fc64dd9/cover-_DS.jpg/400x400cc.jpg', 'twitter': 'Мое открытие на @Shazam: (G)I-DLE – Hann (Alone).', 'html': 'https://www.shazam.com/snippets/email-share/435859252?lang=ru&country=RU', 'avatar': 'https://is1-ssl.mzstatic.com/image/thumb/AMCArtistImages112/v4/7b/6a/c8/7b6ac8cd-ca94-49b8-6245-377ff959ace5/49edeb41-5a0d-42b3-957a-e0e796eea540_ami-identity-da9dd3316026fa2554d986133c5e010a-2022-10-17T09-37-55.772Z_cropped.png/800x800cc.jpg', 'snapchat': 'https://www.shazam.com/partner/sc/track/435859252'}, 'hub': {'type': 'APPLEMUSIC', 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic_{scalefactor}.png', 'actions': [{'name': 'apple', 'type': 'applemusicplay', 'id': '1426297999'}, {'name': 'apple', 'type': 'uri', 'uri': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ec/7c/fe/ec7cfe1d-5aca-d52e-902d-263d8681a81f/mzaf_820439447663730075.plus.aac.ep.m4a'}], 'options': [{'caption': 'ОТКРЫТЬ В', 'actions': [{'name': 'hub:applemusic:deeplink', 'type': 'applemusicopen', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}, {'name': 'hub:applemusic:deeplink', 'type': 'uri', 'uri': 'https://music.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=music&itsct=Shazam_ios'}], 'beacondata': {'type': 'open', 'providername': 'applemusic'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/overflow-open-option_{scalefactor}.png', 'type': 'open', 'listcaption': 'Открыть в Apple Music', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/applemusic-overflow_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'applemusic'}, {'caption': 'КУПИТЬ', 'actions': [{'type': 'uri', 'uri': 'https://itunes.apple.com/ru/album/hann-alone/1426297548?i=1426297999&mttnagencyid=s2n&mttnsiteid=125115&mttn3pid=Apple-Shazam&mttnsub1=Shazam_ios&mttnsub2=5348615A-616D-3235-3830-44754D6D5973&itscg=30201&app=itunes&itsct=Shazam_ios'}], 'beacondata': {'type': 'buy', 'providername': 'itunes'}, 'image': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'type': 'buy', 'listcaption': 'Купить на iTunes', 'overflowimage': 'https://images.shazam.com/static/icons/hub/ios/v5/itunes-overflow-buy_{scalefactor}.png', 'colouroverflowimage': False, 'providername': 'itunes'}], 'providers': [{'caption': 'Открыть в Spotify', 'images': {'overflow': 'https://images.shazam.com/static/icons/hub/ios/v5/spotify-overflow_{scalefactor}.png', 'default': 'https://images. ...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15532\2136911390.py in <module>
#       6 recognize_generator = shazam.recognizeSong()
#       7 while True:
# ----> 8         print(next(recognize_generator)) # current offset & shazam response to recognize requests
#
# StopIteration:

# %%
try:
    next(recognize_generator)
except StopIteration:
    print("Yes")
# Out:
# Yes

# %%
def get_mp3_name(mp3_file,get_all_possible=False):
    """
    Takes in two inputs. mp3_file -> A string and get_all_possible -> a boolean value.
    Returns a list of dictionaries where key -> Artist name, value -> Title of song.
    
    mp3_file -> Name of the file
    [including directory in case it's not located in the same directory as the code.]
    Example : "D:/Problem Music/Heheh.mp3"
    
    get_all_possible -> If true, gets comparison from shazam for the entire duration of the song. 
                     -> Else returns the first correct comparison.
    """
    mp3_file_content_to_recognize = open(mp3_file, 'rb').read()
    shazam = Shazam(mp3_file_content_to_recognize)
    recognize_generator = shazam.recognizeSong()
    count=0
    LIST=list()
    while True:
        try:
            L=next(recognize_generator)
            LIST.append({L[1]['track']['subtitle']:L[1]['track']['title']})
            count+=1
        except StopIteration:
            print("Couldn't find any other matches")
            break
        except KeyError:
            break
        except: #CouldntDecodeError:
            break
        #If statement to get just the first match.
        #To get all possible matches, no need for this if statement.
        if(get_all_possible==False):
            if(count==1):
                #print(L[1]['track']['subtitle']+" - "+L[1]['track']['title'])
                #if(input("Is the match correct [Y/N] : ")=='Y'):
                    #break
                #else:
                    #print("All possible matches : ")
                break
    LIST=list(k for k,_ in itertools.groupby(LIST))
    return LIST

# %%
start_time = time.time()
mp3_file='Dance Challenge - Bailar.mp3'
print(get_mp3_name(mp3_file,get_all_possible=True))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'Dance Challenge': 'Bailar'}]
# --- 109.9614748954773 seconds ---

# %%
def GET_NAME(mp3_file=None,directory=None,rename=False):    
    """
    Function to shazam either one particular mp3 file or an entire directory 
    with an option to rename with the comparison from shazam.
    
    mp3_file (String) -> directory+mp3_filename in case just for one file.
    Example : "D:/Problem Music/Heheh.mp3"
    
    directory (String) -> directory path which has the mp3 files we have to shazam. 
    
    rename (Boolean) -> True if we want to rename with the shazam comparison
                        False if we simply want to print out the names. 
    """
    start_time = time.time()
    if(mp3_file == None and directory):
        file_list=glob(directory+"*.mp3")
        file_list=[name.replace(directory[:-1]+"\\","") for name in file_list]
        for i in file_list:
            print(i.replace(".mp3",""),end=" : ")
            L=get_mp3_name(directory+i,False)
            if(len(L)<1):
                print("Couldn't find a match")
            else:
                song,=list(L[0].items())
                print(song[0]+" - "+song[1])
                if(rename):      
                    os.rename(directory+i, directory+song[0]+" - "+song[1]+".mp3")
                    print(i+" renamed to "+song[0]+" - "+song[1])
    elif(mp3_file):
        L=get_mp3_name(directory+i,False)
        if(len(L)<1):
            print("Couldn't find a match")
        else:
            print(L)
            song,=list(L[0].items())
            if(rename):      
                os.rename(directory+i, directory+song[0]+" - "+song[1]+".mp3")
                print(i+" renamed to "+song[0]+" - "+song[1])
    print("Execution Time :  %s seconds" % (time.time() - start_time))

# %%
GET_NAME(None,"D:/Problem Music/",False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13024\1113213322.py in <module>
# ----> 1 GET_NAME(None,"D:/Problem Music/",False)
#
# NameError: name 'GET_NAME' is not defined

# %%
help(GET_NAME)
# Out:
# Help on function GET_NAME in module __main__:
#
# GET_NAME(mp3_file=None, directory=None, rename=False)
#     Function to shazam either one particular mp3 file or an entire directory
#     with an option to rename with the comparison from shazam.
#
#     mp3_file (String) -> directory+mp3_filename in case just for one file.
#     Example : "D:/Problem Music/Heheh.mp3"
#
#     directory (String) -> directory path which has the mp3 files we have to shazam.
#
#     rename (Boolean) -> True if we want to rename with the shazam comparison
#                         False if we simply want to print out the names.
